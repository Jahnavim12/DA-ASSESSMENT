# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahnavim12/DA-ASSESSMENT/blob/main/DA_ASSESSMENT(67G5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import re

# %%
df =pd.read_csv("/content/car_price_performance.csv")

# %%
df
# Out:
#         Brand  Price  Horsepower  Fuel Efficiency
# 0     Brand C  91942         382             15.3
# 1     Brand A  70075         197             32.6
# 2     Brand C  84524         188             34.9
# 3     Brand E  68939         258             15.1
# 4     Brand X  66505         277             13.0
# ...       ...    ...         ...              ...
# 1995  Brand Z  34535         196             15.2
# 1996  Brand C  35215         377             25.3
# 1997  Brand E  72980         294             21.8
# 1998  Brand Z  55921         443             11.0
# 1999  Brand B  95051         225             12.4
#
# [2000 rows x 4 columns]

# %%
brand_avg_prices=df.groupby('Brand')['Price'].mean().sort_values(ascending=False)
brand_avg_prices
# Out:
# Brand
# Brand D    65498.701681
# Brand X    65405.884259
# Brand Z    65244.331818
# Brand C    64707.967890
# Brand B    64686.641350
# Brand A    64224.495370
# Brand Y    63880.171569
# Brand E    63712.542601
# Brand W    63034.557018
# Name: Price, dtype: float64

# %%
df.shape
# Out:
# (2000, 4)

# %%
# Clean the dataset
df.dropna(inplace=True)

df.shape
# Out:
# (2000, 4)

# %%
dfnobrand = df[df['Brand'].isna()]
dfnobrand
# Out:
# Empty DataFrame
# Columns: [Brand, Price, Horsepower, Fuel Efficiency]
# Index: []

# %%
dfnohp = df[df['Horsepower'].isna()]
dfnohp
# Out:
# Empty DataFrame
# Columns: [Brand, Price, Horsepower, Fuel Efficiency]
# Index: []

# %%
dfnoprice = df[df['Price'].isna()]
dfnoprice
# Out:
# Empty DataFrame
# Columns: [Brand, Price, Horsepower, Fuel Efficiency]
# Index: []

# %%
dfnoprice = df[df['Fuel Efficiency'].isna()]
dfnoprice
# Out:
# Empty DataFrame
# Columns: [Brand, Price, Horsepower, Fuel Efficiency]
# Index: []

# %%
brand_avg_prices = df.groupby('Brand')['Price'].mean().sort_values(ascending=False)
brand_avg_prices.count()
# Out:
# np.int64(9)

# %%
d={}
for i in brand_avg_prices.index:
  print(i)
# Out:
# Brand D
# Brand X
# Brand Z
# Brand C
# Brand B
# Brand A
# Brand Y
# Brand E
# Brand W

# %%
d = {}
j=len(brand_avg_prices)
for i in brand_avg_prices.index:
  d[i] = j
  j-=1
d
# Out:
# {'Brand D': 9,
#  'Brand X': 8,
#  'Brand Z': 7,
#  'Brand C': 6,
#  'Brand B': 5,
#  'Brand A': 4,
#  'Brand Y': 3,
#  'Brand E': 2,
#  'Brand W': 1}

# %%
x=[]
for j in df['Brand']:
  y=d[j]
  x.append(y)
df['Encoded brand']=x
df
# Out:
#         Brand  Price  Horsepower  Fuel Efficiency  Encoded brand
# 0     Brand C  91942         382             15.3              6
# 1     Brand A  70075         197             32.6              4
# 2     Brand C  84524         188             34.9              6
# 3     Brand E  68939         258             15.1              2
# 4     Brand X  66505         277             13.0              8
# ...       ...    ...         ...              ...            ...
# 1995  Brand Z  34535         196             15.2              7
# 1996  Brand C  35215         377             25.3              6
# 1997  Brand E  72980         294             21.8              2
# 1998  Brand Z  55921         443             11.0              7
# 1999  Brand B  95051         225             12.4              5
#
# [2000 rows x 5 columns]

# %%
fe=[]
min=df['Fuel Efficiency'].min()
max=df['Fuel Efficiency'].max()
for i in df['Fuel Efficiency']:
  scaled_value=(i-min)/(max-min)
  fe.append(scaled_value)
df['Scaled Fuel efficiency']=fe
df
# Out:
#         Brand  Price  Horsepower  Fuel Efficiency  Encoded brand  \
# 0     Brand C  91942         382             15.3              6
# 1     Brand A  70075         197             32.6              4
# 2     Brand C  84524         188             34.9              6
# 3     Brand E  68939         258             15.1              2
# 4     Brand X  66505         277             13.0              8
# ...       ...    ...         ...              ...            ...
# 1995  Brand Z  34535         196             15.2              7
# 1996  Brand C  35215         377             25.3              6
# 1997  Brand E  72980         294             21.8              2
# 1998  Brand Z  55921         443             11.0              7
# 1999  Brand B  95051         225             12.4              5
#
#       Scaled Fuel efficiency
# 0                      0.212
# 1                      0.904
# 2                      0.996
# 3                      0.204
# 4                      0.120
# ...

# %%
hp=[]
min=df['Horsepower'].min()
max=df['Horsepower'].max()
for i in df['Horsepower']:
  scaled_value=(i-min)/(max-min)
  hp.append(scaled_value)
df['Scaled Horsepower']=hp
df
# Out:
#         Brand  Price  Horsepower  Fuel Efficiency  Encoded brand  \
# 0     Brand C  91942         382             15.3              6
# 1     Brand A  70075         197             32.6              4
# 2     Brand C  84524         188             34.9              6
# 3     Brand E  68939         258             15.1              2
# 4     Brand X  66505         277             13.0              8
# ...       ...    ...         ...              ...            ...
# 1995  Brand Z  34535         196             15.2              7
# 1996  Brand C  35215         377             25.3              6
# 1997  Brand E  72980         294             21.8              2
# 1998  Brand Z  55921         443             11.0              7
# 1999  Brand B  95051         225             12.4              5
#
#       Scaled Fuel efficiency  Scaled Horsepower
# 0                      0.212             0.7050
# 1                      0.904             0.2425
# ...

# %%
eb=[]
min=df['Encoded brand'].min()
max=df['Encoded brand'].max()
for i in df['Encoded brand']:
  scaled_value=(i-min)/(max-min)
  eb.append(scaled_value)
df['Scaled Encoded brand']=eb
df
# Out:
#         Brand  Price  Horsepower  Fuel Efficiency  Encoded brand  \
# 0     Brand C  91942         382             15.3              6
# 1     Brand A  70075         197             32.6              4
# 2     Brand C  84524         188             34.9              6
# 3     Brand E  68939         258             15.1              2
# 4     Brand X  66505         277             13.0              8
# ...       ...    ...         ...              ...            ...
# 1995  Brand Z  34535         196             15.2              7
# 1996  Brand C  35215         377             25.3              6
# 1997  Brand E  72980         294             21.8              2
# 1998  Brand Z  55921         443             11.0              7
# 1999  Brand B  95051         225             12.4              5
#
#       Scaled Fuel efficiency  Scaled Horsepower  Scaled Encoded brand
# 0                      0.212             0.7050                 0.625
# ...

# %%
df['Performance Index']=(df['Horsepower'] * 0.7 + df['Fuel Efficiency'] * 0.3) / df['Price']

# %%
df
# Out:
#         Brand  Price  Horsepower  Fuel Efficiency  Encoded brand  \
# 0     Brand C  91942         382             15.3              6
# 1     Brand A  70075         197             32.6              4
# 2     Brand C  84524         188             34.9              6
# 3     Brand E  68939         258             15.1              2
# 4     Brand X  66505         277             13.0              8
# ...       ...    ...         ...              ...            ...
# 1995  Brand Z  34535         196             15.2              7
# 1996  Brand C  35215         377             25.3              6
# 1997  Brand E  72980         294             21.8              2
# 1998  Brand Z  55921         443             11.0              7
# 1999  Brand B  95051         225             12.4              5
#
#       Scaled Fuel efficiency  Scaled Horsepower  Scaled Encoded brand  \
# 0                      0.212             0.7050                 0.625
# ...

# %%
df.to_csv('23AG1A67G5.csv', index=False)
